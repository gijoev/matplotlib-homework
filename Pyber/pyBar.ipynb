# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
cityDataFile = "./raw_data/city_data.csv"
rideDataFile = "./raw_data/ride_data.csv"

cityData_df = pd.read_csv(cityDataFile)
rideData_df = pd.read_csv(rideDataFile)

print(cityData_df)
# Out:
#                      city  driver_count      type
# 0              Kelseyland            63     Urban
# 1              Nguyenbury             8     Urban
# 2            East Douglas            12     Urban
# 3           West Dawnfurt            34     Urban
# 4          Rodriguezburgh            52     Urban
# 5       South Josephville             4     Urban
# 6        West Sydneyhaven            70     Urban
# 7             Travisville            37     Urban
# 8             Torresshire            70     Urban
# 9               Lisaville            66     Urban
# 10              Mooreview            34     Urban
# 11             Smithhaven            67     Urban
# 12            Carrollfort            55     Urban
# 13        Port Josephfurt            28     Urban
# 14       Lake Jeffreyland            15     Urban
# 15            South Louis            12     Urban
# 16             West Peter            61     Urban
# 17        Kimberlychester            13     Urban
# ...

# %%
x = cityData_df.groupby(["type"])
x.head()
# Out:
#                      city  driver_count      type
# 0              Kelseyland            63     Urban
# 1              Nguyenbury             8     Urban
# 2            East Douglas            12     Urban
# 3           West Dawnfurt            34     Urban
# 4          Rodriguezburgh            52     Urban
# 66            Carrollbury             4  Suburban
# 67         Williamchester            26  Suburban
# 68       New Michelleberg             9  Suburban
# 69              West Evan             4  Suburban
# 70     South Gracechester            19  Suburban
# 108  South Elizabethmouth             3     Rural
# 109         East Troybury             3     Rural
# 110             Kinghaven             3     Rural
# 111          New Johnbury             6     Rural
# 112              Erikport             3     Rural

# %%
combData = pd.merge(cityData_df,rideData_df,how='left',on=['city','city'])
print(combData)
# Out:
#                 city  driver_count   type                 date   fare  \
# 0         Kelseyland            63  Urban  2016-08-19 04:27:52   5.51
# 1         Kelseyland            63  Urban  2016-04-17 06:59:50   5.54
# 2         Kelseyland            63  Urban  2016-05-04 15:06:07  30.54
# 3         Kelseyland            63  Urban  2016-01-25 20:44:56  12.08
# 4         Kelseyland            63  Urban  2016-08-09 18:19:47  17.91
# 5         Kelseyland            63  Urban  2016-10-24 15:15:46  33.56
# 6         Kelseyland            63  Urban  2016-06-06 13:54:23  20.81
# 7         Kelseyland            63  Urban  2016-08-10 07:02:40  44.53
# 8         Kelseyland            63  Urban  2016-07-05 17:37:13  29.02
# 9         Kelseyland            63  Urban  2016-04-25 02:18:31  20.05
# 10        Kelseyland            63  Urban  2016-01-25 08:47:09   9.29
# 11        Kelseyland            63  Urban  2016-11-10 01:57:14  20.58
# ...

# %%
z = combData[combData["type"] == 'Urban']
print(z)
# Out:
#               city  driver_count   type                 date   fare  \
# 0       Kelseyland            63  Urban  2016-08-19 04:27:52   5.51
# 1       Kelseyland            63  Urban  2016-04-17 06:59:50   5.54
# 2       Kelseyland            63  Urban  2016-05-04 15:06:07  30.54
# 3       Kelseyland            63  Urban  2016-01-25 20:44:56  12.08
# 4       Kelseyland            63  Urban  2016-08-09 18:19:47  17.91
# 5       Kelseyland            63  Urban  2016-10-24 15:15:46  33.56
# 6       Kelseyland            63  Urban  2016-06-06 13:54:23  20.81
# 7       Kelseyland            63  Urban  2016-08-10 07:02:40  44.53
# 8       Kelseyland            63  Urban  2016-07-05 17:37:13  29.02
# 9       Kelseyland            63  Urban  2016-04-25 02:18:31  20.05
# 10      Kelseyland            63  Urban  2016-01-25 08:47:09   9.29
# 11      Kelseyland            63  Urban  2016-11-10 01:57:14  20.58
# 12      Kelseyland            63  Urban  2016-08-15 11:55:02  27.45
# ...

# %%
z['city'].value_counts()
# Out:
# Swansonbury         34
# Port Johnstad       34
# South Louis         32
# Jacobfort           31
# Williamshire        31
# West Peter          31
# Alvarezhaven        31
# Arnoldview          31
# Stewartview         30
# West Brandy         30
# West Oscar          29
# West Dawnfurt       29
# Carrollfort         29
# Lisaville           28
# New David           28
# East Erin           28
# New Andreamouth     28
# Kelseyland          28
# Edwardsbury         27
# Port Samantha       27
# Kimberlychester     27
# Sandymouth          27
# Smithhaven          27
# Sarabury            27
# Alyssaberg          26
# Spencertown         26
# Nguyenbury          26
# Torresshire         26
# Davistown           25
# Lake Jennaton       25
#                     ..
# Fosterside          24
# Rodriguezburgh      23
# Russellport         23
# Travisville         23
# Lisatown            23
# Port Josephfurt     22
# New Aaron           22
# Lake Sarashire      22
# Antoniomouth        22
# ...

# %%
z(g)
